# %%
import pandas as pd

# %%
df = pd.read_table('./yfcc100m_dataset-0',sep='\t',header=None)

# %%
df.head()
# Out:
#             0             1              2                      3   \
# 0   6985418911  39089491@N00      nino63004  2012-02-16 09:56:37.0
# 1  10201275523  55289779@N00     booledozer  2013-10-09 15:30:13.0
# 2   2297552664   8134076@N03  nathalie.cone  2008-02-27 08:14:36.0
# 3   7289030198  53430201@N03   sarabeephoto  2012-05-28 00:23:30.0
# 4   4140939180  12940050@N02    enjoiskate8  2009-11-21 08:03:30.0
#
#            4                               5   \
# 0  1331840483     Canon+PowerShot+ELPH+310+HS
# 1  1381464628              Panasonic+DMC-ZS10
# 2  1204166915           Canon+PowerShot+S2+IS
# 3  1338233199     Canon+EOS+DIGITAL+REBEL+XSi
# 4  1259417601  PENTAX+Corporation+PENTAX+K10D
#
#                                                   6   \
# 0                                           IMG_0520
# 1  Images+from+the+intersection+of+Parliament+and...
# 2                          denise%27s+peanut+chicken
# 3                             blip+fest+2012+night+3
# 4                                           IMGP7409
#
#                                                   7   \
# 0                                                NaN
# 1                                                NaN
# 2  recipe+here%3A+%3Ca+href%3D%22http%3A%2F%2Fall...
# 3                                                NaN
# 4                                                NaN
#
#                                                   8    9  ...  \
# 0  canon,canon+powershot+hs+310,carnival+escatay,...  NaN ...
# 1                                                NaN  NaN ...
# 2                                                NaN  NaN ...
# 3  blip,blip12ny,blipfest,blipfestival,blipfestiv...  NaN ...
# 4  2009,amsterdam,clinquest,fall,netherlands,nov,...  NaN ...
#
#                                                   13  \
# 0  http://www.flickr.com/photos/39089491@N00/6985...
# 1  http://www.flickr.com/photos/55289779@N00/1020...
# 2  http://www.flickr.com/photos/8134076@N03/22975...
# 3  http://www.flickr.com/photos/53430201@N03/7289...
# 4  http://www.flickr.com/photos/12940050@N02/4140...
#
#                                                   14  \
# 0  http://farm8.staticflickr.com/7205/6985418911_...
# 1  http://farm6.staticflickr.com/5465/10201275523...
# 2  http://farm4.staticflickr.com/3171/2297552664_...
# 3  http://farm8.staticflickr.com/7231/7289030198_...
# 4  http://farm3.staticflickr.com/2565/4140939180_...
#
#                                            15  \
# 0  Attribution-NonCommercial-NoDerivs License
# 1              Attribution-ShareAlike License
# 2  Attribution-NonCommercial-NoDerivs License
# 3  Attribution-NonCommercial-NoDerivs License
# 4  Attribution-NonCommercial-NoDerivs License
#
#                                                   16    17 18          19  \
# 0  http://creativecommons.org/licenses/by-nc-nd/2.0/  7205  8  df7747990d
# 1     http://creativecommons.org/licenses/by-sa/2.0/  5465  6  3e6ea67c7f
# 2  http://creativecommons.org/licenses/by-nc-nd/2.0/  3171  4  1ee0e8855d
# 3  http://creativecommons.org/licenses/by-nc-nd/2.0/  7231  8  1f1ba44113
# 4  http://creativecommons.org/licenses/by-nc-nd/2.0/  2565  3  07aeded917
#
#            20   21 22
# 0  692d7e0a7f  jpg  0
# 1  f400826feb  jpg  0
# 2  bed1547a29  jpg  0
# 3  bc36823aec  jpg  0
# 4  da7f4b048e  jpg  0
#
# [5 rows x 23 columns]

# %%
columns = {0:'id',1:'user_nid',2:'user_nickname',3:'date_taken',4:'date_uploaded',
          5:'capture_device',6:'title',7:'descr',8:'user_tags',9:'machine_tags',
          10:'lon',11:'lat',12:'accuracy',13:'photo_url',14:'dl_url',15:'license_name',
          16:'license_url',17:'server_id',18:'farm_id',19:'secret',20:'secret_orig',
          21:'ext',22:'marker'}

df.rename(columns=columns,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000000 entries, 0 to 9999999
# Data columns (total 23 columns):
# id                int64
# user_nid          object
# user_nickname     object
# date_taken        object
# date_uploaded     int64
# capture_device    object
# title             object
# descr             object
# user_tags         object
# machine_tags      object
# lon               float64
# lat               float64
# accuracy          float64
# photo_url         object
# dl_url            object
# license_name      object
# license_url       object
# server_id         int64
# farm_id           int64
# secret            object
# secret_orig       object
# ext               object
# marker            int64
# dtypes: float64(3), int64(5), object(15)
# memory usage: 1.8+ GB

# %%
from dateutil import parser

# %%
n = len(df.index)

# %%
parsed = []
for i in range(n):
    if df[3].loc[i]=='null':
        parsed.append('nan')
    else:
        tmp = parser.parse(df[3].loc[i])
        parsed.append(tmp)

# %%
len(parsed)
# Out:
# 10000000

# %%
df[['lat','lon']].head()
# Out:
#          lat        lon
# 0  24.550558 -81.804885
# 1  43.649708 -79.365637
# 2        NaN        NaN
# 3  40.740067 -73.985495
# 4        NaN        NaN

# %%
df.head()
# Out:
#             id      user_nid  user_nickname             date_taken  \
# 0   6985418911  39089491@N00      nino63004  2012-02-16 09:56:37.0
# 1  10201275523  55289779@N00     booledozer  2013-10-09 15:30:13.0
# 2   2297552664   8134076@N03  nathalie.cone  2008-02-27 08:14:36.0
# 3   7289030198  53430201@N03   sarabeephoto  2012-05-28 00:23:30.0
# 4   4140939180  12940050@N02    enjoiskate8  2009-11-21 08:03:30.0
#
#    date_uploaded                  capture_device  \
# 0     1331840483     Canon+PowerShot+ELPH+310+HS
# 1     1381464628              Panasonic+DMC-ZS10
# 2     1204166915           Canon+PowerShot+S2+IS
# 3     1338233199     Canon+EOS+DIGITAL+REBEL+XSi
# 4     1259417601  PENTAX+Corporation+PENTAX+K10D
#
#                                                title  \
# 0                                           IMG_0520
# 1  Images+from+the+intersection+of+Parliament+and...
# 2                          denise%27s+peanut+chicken
# 3                             blip+fest+2012+night+3
# 4                                           IMGP7409
#
#                                                descr  \
# 0                                                NaN
# 1                                                NaN
# 2  recipe+here%3A+%3Ca+href%3D%22http%3A%2F%2Fall...
# 3                                                NaN
# 4                                                NaN
#
#                                            user_tags machine_tags  ...    \
# 0  canon,canon+powershot+hs+310,carnival+escatay,...          NaN  ...
# 1                                                NaN          NaN  ...
# 2                                                NaN          NaN  ...
# 3  blip,blip12ny,blipfest,blipfestival,blipfestiv...          NaN  ...
# 4  2009,amsterdam,clinquest,fall,netherlands,nov,...          NaN  ...
#
#                                            photo_url  \
# 0  http://www.flickr.com/photos/39089491@N00/6985...
# 1  http://www.flickr.com/photos/55289779@N00/1020...
# 2  http://www.flickr.com/photos/8134076@N03/22975...
# 3  http://www.flickr.com/photos/53430201@N03/7289...
# 4  http://www.flickr.com/photos/12940050@N02/4140...
#
#                                               dl_url  \
# 0  http://farm8.staticflickr.com/7205/6985418911_...
# 1  http://farm6.staticflickr.com/5465/10201275523...
# 2  http://farm4.staticflickr.com/3171/2297552664_...
# 3  http://farm8.staticflickr.com/7231/7289030198_...
# 4  http://farm3.staticflickr.com/2565/4140939180_...
#
#                                  license_name  \
# 0  Attribution-NonCommercial-NoDerivs License
# 1              Attribution-ShareAlike License
# 2  Attribution-NonCommercial-NoDerivs License
# 3  Attribution-NonCommercial-NoDerivs License
# 4  Attribution-NonCommercial-NoDerivs License
#
#                                          license_url server_id farm_id  \
# 0  http://creativecommons.org/licenses/by-nc-nd/2.0/      7205       8
# 1     http://creativecommons.org/licenses/by-sa/2.0/      5465       6
# 2  http://creativecommons.org/licenses/by-nc-nd/2.0/      3171       4
# 3  http://creativecommons.org/licenses/by-nc-nd/2.0/      7231       8
# 4  http://creativecommons.org/licenses/by-nc-nd/2.0/      2565       3
#
#        secret  secret_orig  ext marker
# 0  df7747990d   692d7e0a7f  jpg      0
# 1  3e6ea67c7f   f400826feb  jpg      0
# 2  1ee0e8855d   bed1547a29  jpg      0
# 3  1f1ba44113   bc36823aec  jpg      0
# 4  07aeded917   da7f4b048e  jpg      0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000000 entries, 0 to 9999999
# Data columns (total 23 columns):
# id                int64
# user_nid          object
# user_nickname     object
# date_taken        object
# date_uploaded     int64
# capture_device    object
# title             object
# descr             object
# user_tags         object
# machine_tags      object
# lon               float64
# lat               float64
# accuracy          float64
# photo_url         object
# dl_url            object
# license_name      object
# license_url       object
# server_id         int64
# farm_id           int64
# secret            object
# secret_orig       object
# ext               object
# marker            int64
# dtypes: float64(3), int64(5), object(15)
# memory usage: 1.8+ GB
